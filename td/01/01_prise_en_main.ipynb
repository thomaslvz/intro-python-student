# %% [markdown]
# # Séance 1 — Prise en main de Jupyterlab
#
#
# Objectifs : vérifier votre installation, créer votre arborescence de travail, manipuler un notebook, exécuter un script depuis le terminal.
#
# > Conventions du cours : les énoncés sont en français, **le code et ses commentaires en anglais**. Les cellules à compléter contiennent `# TODO`. Les questions et tâches à réaliser sont précédées par ❓ ou 👉.

# %% [markdown]
# ## Organiser ses fichiers
#
# Repérez l'explorateur de fichier dans le panneau de gauche et ouvrez-le. Vous devriez voir le contenu du dossier dédié au TD1, et le chemin vers ce dossier, sous la forme `📁/td/01`. Vous pouvez naviguer entre les dossiers en cliquant dessus.
#
# ❓ Ouvrez le dossier "racine" en cliquant sur `📁`.
#
# Vous devriez voir l'arborescence du dossier `intro-python` :
#
# ```
# intro-python/
# ├── data/                 <-- Nous y stockerons des données utiles aux exercices
# └── td/                   <-- Nous y stockerons les notebooks des TDs
# ```
#
# Si ce n'est pas le cas, appelez l'enseignant.
#
# NB : 💡 le dossier racine correspond au dossier `intro-python` car c'est dans ce dossier que nous avons ouvert *JupyterLab*.

# %% [markdown]
# ❓ Pour apprendre à utiliser l'explorateur de fichier, réalisez les deux actions suivantes :
# 1. Créez un dossier `travail-perso` dans le dossier `intro-python`. Il servira a stocker vos fichiers personnels sur ce cours.
# 2. Déplacez le fichier `sample.txt` du dossier `data` vers le dossier du TD n°1. Vous pouvez utiliser les fonctions Couper / Coller.

# %% [markdown]
# La cellule ci-dessous contient du code Python. Inutile d'essayer de le comprendre pour le moment. Pour exécuter le code il y a trois manières de procéder :
# 1. Cliquer sur la cellule puis sur le bouton ▶ en haut de la fenêtre
# 2. Cliquer sur la cellule puis aller dans le menu `Run` puis `Run Selected Cells`
# 2. Cliquer sur la cellule puis touches `Shift` + `Enter
#
# ❓ Exécutez la cellule ci-dessous. Si elle déclenche une erreur, c'est que vous n'avez pas réalisez les 2 actions demandées dans la question précédente. Corrigez les erreurs avnat de continuer.

# %%
import os

try:
    assert os.path.exists("../../travail-perso"), "Le dossier travail-perso n'a pas été créé"
    assert os.path.exists("sample.txt"), "Le fichier sample.txt n'a pas été déplacé"
    assert os.path.exists("../../data/sample.txt"), "Le fichier sample.txt a été copié au bon endroit mais l'original est toujours dans le dossier /data"
    print("✅ Tout va bien, vous pouvez continuer")
    
except AssertionError as e:
    print(f"❌ Erreur : {e}")

# %% [markdown]
# ## Manipuler les cellules
#
# ❓ A faire :
#
# 1. Ajoutez une cellule **Markdown** sous celle-ci (Cliquez sur cette cellule, puis touche `B`, puis `M`). Dans la cellule, écrivez-y votre prénom en gras et votre nom en caractères normal. Si vous ne savez pas faire le **gras** en langage Markdown, allez voir [ce guide](https://www.markdownguide.org/basic-syntax/).
# 2. En dessous, ajoutez une cellule de **code** qui calcule `7 * 6` et affiche le résultat.
# 3. Supprimez la cellule contenant `print("cellule à supprimer")` (`D`, `D`).

# %%
print("cellule à supprimer")

# %% [markdown]
# ## L'ordre d'exécution compte
#
# Exécutez la cellule A, puis B, puis à nouveau B. Comprenez vous pourquoi `counter` a augmenté ?
#
# Dans le menu, cliquez sur *Kernel → Restart Kernel*. Relancez à nouveau les cellules A puis B. Que s'est-il passé ?
#
# 💡 On retiendra que python conserve en mémoire les variables qui ont été nommées précédemment, et que le *Kernel* (noyau python) doit être relancé pour tout recommencer à zéro.

# %%
# cell A
counter = 0

# %%
# cell B
counter = counter + 1
print(counter)

# %% [markdown]
# ## Variables et `print`
#
# La cellule ci-dessouis a été exécutée.
#
# ❓ Comprenez vous à quoi sert la commande `print` ?

# %%
print("Hello !")

name = "Alice"
print("My name is", name)

age = 22
print("Next year, I will be", age+1)

# %% [markdown]
# ❓ Complétez la cellule ci-dessous pour calculer et afficher le PIB par habitant.
#
# <details>
# <summary>Indice</summary>
#
# Indice avec les unités proposées, on a $\text{PIB par habitant} = \dfrac{\text{PIB} \times 10^9}{\text{population} \times 10^6}$.
# </details>

# %%
gdp_billions = 2900      # billions of euros
population_millions = 68.46
# TODO: compute gdp_per_capita and print it

# %% [markdown]
# ## Lire une erreur et débuguer son code
#
# Chaque cellule ci-dessous contient une erreur.
#
# ❓ Pour chaque cellule :
# - Exécutez-la,
# - Lisez le message d'erreur **en partant du bas**,
# - Corrigez l'erreur.

# %%
unemployment_rate = 7.3
print(unemploymentrate)

# %%
print("Inflation :", 3.2

# %%
print("Le taux de chômage est de " + 7.3 + " %")

# %% [markdown]
# ## Un script Python dans le terminal
#
# 1. Ouvrez le fichier `hello.py` fourni (double-clic dans l'explorateur) et lisez-le.
# 2. En cliquant sur le *Launcher* (Icone `+`), ouvrez un nouveau **Terminal**.
# 3. Tapez `python hello.py` puis Entrée. Le script s'exécute dans le Terminal.
# 4. Modifiez le script pour qu'il affiche aussi la population (68,46 millions), enregistrez (`Ctrl + S`), relancez-le.
#
# 💡 Retenons une différence entre les scripts et les notebooks : un script s'exécute d'un bloc, du début à la fin, et n'affiche que ce que `print` demande.

# %% [markdown]
# ## Lire la documentation officielle
#
# Il est souvent inutile de connaître toutes les fonctions et syntaxes par coeur. En revanche, il faut savoir lire la documentation officielle pour trouver la manière d'utiliser les fonctions.
#
# ❓ Lisez la [documentation officielle](https://docs.python.org/fr/3.7/library/functions.html?highlight=round#round) concernant la fonction `round`. Ensuite, utilisez `round` pour arrondir `population_millions` à la dizaine de millions (regardez ce que fait un second argument négatif).

# %%
# TODO: round population_millions to the nearest ten
