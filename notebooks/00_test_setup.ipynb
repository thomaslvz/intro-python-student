# %% [markdown]
# # Vérification du setup Python
#
# Ce notebook permet de vérifier que l'installation de Python est correcte.
#
# Si une erreur survient, contacter l'enseignant.
#
# Pour exécuter le code, cliquer sur le bouton "Run" en haut à droite de la cellule de code, ou utiliser le raccourci clavier `Shift + Enter`.

# %% [markdown]
# ## Vérification de l'environnement
#
# La cellule ci-dessous doit renvoyer:
#
# ```
# ```

# %%
import sys
import numpy as np
import pandas as pd
import matplotlib
import statsmodels

print("Python:", sys.version)
print("NumPy:", np.__version__)
print("Pandas:", pd.__version__)
print("Matplotlib:", matplotlib.__version__)
print("Statsmodels:", statsmodels.__version__)
# Out:
# Python: 3.12.14 (main, Sep  2 2026, 23:27:36) [GCC 15.3.0]
# NumPy: 2.5.3
# Pandas: 3.0.5
# Matplotlib: 3.11.2
# Statsmodels: 0.15.0
